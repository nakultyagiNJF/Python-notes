# %%
print("start code")

try:
    print(name)
except:
    print("bhai aisa hai ki error aa chuki hai.")

print("end code")
# Out:
# start code
# bhai aisa hia ki error aa chuki hai.
# end code

# %%
print("start code")

try:
    print(name)
except Exception as e:
    print(e)

print("end code")
# Out:
# start code
# name 'name' is not defined
# end code

# %%
print("start code")

def sayhi():
    print("Hello Shree!")

def saybye():
    print(bye)

try:
    sayhi()
    saybye()
except Exception as e:
    print(e)

print("end code")
# Out:
# start code
# Hello Shree!
# name 'bye' is not defined
# end code

# %%
print("start code")

try:
    a = 10
    b = "10"
    print(a + b)
except TypeError as t:
    print(t)

print("end code")
# Out:
# start code
# unsupported operand type(s) for +: 'int' and 'str'
# end code

# %%
print("start code")

try:
    print("Hi Shree!!")
except Exception as e:
    print(e)
else:
    print("Balle Balle, koi error nahin hai.")

print("end code")
# Out:
# start code
# Hi Shree!!
# Balle Balle, koi error nahin hai.
# end code

# %%
print("start code")

try:
    print(hello)
except Exception as e:
    print(e)
else:
    print("Bhai sab okay hai.")
finally:
    print("ye code hamesha chalega, chahe error aaye ya na.")

print("end code")
# Out:
# start code
# name 'hello' is not defined
# ye code hamesha chalega, chahe error aaye ya na.
# end code
